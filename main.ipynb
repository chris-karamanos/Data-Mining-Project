# %%
import glob, pandas as pd
import numpy as np
import glob
import matplotlib.pyplot as plt
import seaborn as sns

# %%
files = sorted(glob.glob("1st_task/data/chunks/part_*.parquet"))
df = pd.read_parquet(files[0])  # inspect the first chunk

# %%
df.head()
# Out:
#                                    Flow ID        Src IP  Src Port  \
# 0   192.168.1.90-192.168.1.3-53930-64738-6  192.168.1.90   53930.0
# 1   192.168.1.3-192.168.1.90-64738-37700-6   192.168.1.3   64738.0
# 2      192.168.1.3-192.168.1.90-22-40854-6   192.168.1.3      22.0
# 3   192.168.1.70-192.168.1.3-55422-64738-6  192.168.1.70   55422.0
# 4  192.168.1.90-192.168.1.3-59658-64738-17  192.168.1.90   59658.0
#
#          Dst IP  Dst Port  Protocol               Timestamp  Flow Duration  \
# 0   192.168.1.3     64738       6.0  01/01/1970 07:41:46 AM     52601172.0
# 1  192.168.1.90     37700       6.0  01/01/1970 07:41:46 AM    119106944.0
# 2  192.168.1.90     40854       6.0  01/01/1970 07:41:46 AM         5589.0
# 3   192.168.1.3     64738       6.0  01/01/1970 07:41:47 AM    118166560.0
# 4   192.168.1.3     64738      17.0  01/01/1970 07:41:50 AM    119988384.0
#
#    Total Fwd Packet  Total Bwd packets  ...  Active Std  Active Max  \
# 0            1701.0             1793.0  ...         0.0         0.0
# 1              36.0               57.0  ...   3416174.0  19996926.0
# 2               1.0                1.0  ...         0.0         0.0
# 3            3932.0             4196.0  ...         0.0         0.0
# 4              25.0             6795.0  ...         0.0         0.0
#
#    Active Min  Idle Mean     Idle Std   Idle Max   Idle Min   Label  \
# 0         0.0        0.0     0.000000        0.0        0.0  Benign
# 1  14078617.0  5001511.0  1737.400024  5003516.0  5000449.0  Benign
# 2         0.0        0.0     0.000000        0.0        0.0  Benign
# 3         0.0        0.0     0.000000        0.0        0.0  Benign
# 4         0.0        0.0     0.000000        0.0        0.0  Benign
#
#    Traffic Type  Traffic Subtype
# 0         Audio            Audio
# 1         Audio            Audio
# 2         Audio            Audio
# 3         Audio            Audio
# 4         Audio            Audio
#
# [5 rows x 86 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 86 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   Flow ID                     1000000 non-null  category
#  1   Src IP                      1000000 non-null  category
#  2   Src Port                    1000000 non-null  float32
#  3   Dst IP                      1000000 non-null  category
#  4   Dst Port                    1000000 non-null  int32
#  5   Protocol                    1000000 non-null  float32
#  6   Timestamp                   1000000 non-null  category
#  7   Flow Duration               1000000 non-null  float32
#  8   Total Fwd Packet            1000000 non-null  float32
#  9   Total Bwd packets           1000000 non-null  float32
#  10  Total Length of Fwd Packet  1000000 non-null  float32
#  11  Total Length of Bwd Packet  1000000 non-null  float32
#  12  Fwd Packet Length Max       1000000 non-null  float32
#  13  Fwd Packet Length Min       1000000 non-null  float32
#  14  Fwd Packet Length Mean      1000000 non-null  float32
#  15  Fwd Packet Length Std       1000000 non-null  float32
#  16  Bwd Packet Length Max       1000000 non-null  float32
#  17  Bwd Packet Length Min       1000000 non-null  float32
#  18  Bwd Packet Length Mean      1000000 non-null  float32
#  19  Bwd Packet Length Std       1000000 non-null  float32
#  20  Flow Bytes/s                1000000 non-null  float32
#  21  Flow Packets/s              1000000 non-null  float32
#  22  Flow IAT Mean               1000000 non-null  float32
#  23  Flow IAT Std                1000000 non-null  float32
#  24  Flow IAT Max                1000000 non-null  float32
#  25  Flow IAT Min                1000000 non-null  float32
#  26  Fwd IAT Total               1000000 non-null  float32
#  27  Fwd IAT Mean                1000000 non-null  float32
#  28  Fwd IAT Std                 1000000 non-null  float32
#  29  Fwd IAT Max                 1000000 non-null  float32
#  30  Fwd IAT Min                 1000000 non-null  float32
#  31  Bwd IAT Total               1000000 non-null  float32
#  32  Bwd IAT Mean                1000000 non-null  float32
#  33  Bwd IAT Std                 1000000 non-null  float32
#  34  Bwd IAT Max                 1000000 non-null  float32
#  35  Bwd IAT Min                 1000000 non-null  float32
#  36  Fwd PSH Flags               1000000 non-null  float32
#  37  Bwd PSH Flags               1000000 non-null  float32
#  38  Fwd URG Flags               1000000 non-null  float32
#  39  Bwd URG Flags               1000000 non-null  float32
#  40  Fwd Header Length           1000000 non-null  float32
#  41  Bwd Header Length           1000000 non-null  float32
#  42  Fwd Packets/s               1000000 non-null  float32
#  43  Bwd Packets/s               1000000 non-null  float32
#  44  Packet Length Min           1000000 non-null  float32
#  45  Packet Length Max           1000000 non-null  float32
#  46  Packet Length Mean          1000000 non-null  float32
#  47  Packet Length Std           1000000 non-null  float32
#  48  Packet Length Variance      1000000 non-null  float32
#  49  FIN Flag Count              1000000 non-null  float32
#  50  SYN Flag Count              1000000 non-null  float32
#  51  RST Flag Count              1000000 non-null  float32
#  52  PSH Flag Count              1000000 non-null  float32
#  53  ACK Flag Count              1000000 non-null  float32
#  54  URG Flag Count              1000000 non-null  float32
#  55  CWR Flag Count              1000000 non-null  float32
#  56  ECE Flag Count              1000000 non-null  float32
#  57  Down/Up Ratio               1000000 non-null  float32
#  58  Average Packet Size         1000000 non-null  float32
#  59  Fwd Segment Size Avg        1000000 non-null  float32
#  60  Bwd Segment Size Avg        1000000 non-null  float32
#  61  Fwd Bytes/Bulk Avg          1000000 non-null  float32
#  62  Fwd Packet/Bulk Avg         1000000 non-null  float32
#  63  Fwd Bulk Rate Avg           1000000 non-null  float32
#  64  Bwd Bytes/Bulk Avg          1000000 non-null  float32
#  65  Bwd Packet/Bulk Avg         1000000 non-null  float32
#  66  Bwd Bulk Rate Avg           1000000 non-null  float32
#  67  Subflow Fwd Packets         1000000 non-null  float32
#  68  Subflow Fwd Bytes           1000000 non-null  float32
#  69  Subflow Bwd Packets         1000000 non-null  float32
#  70  Subflow Bwd Bytes           1000000 non-null  float32
#  71  FWD Init Win Bytes          1000000 non-null  float32
#  72  Bwd Init Win Bytes          1000000 non-null  float32
#  73  Fwd Act Data Pkts           1000000 non-null  float32
#  74  Fwd Seg Size Min            1000000 non-null  float32
#  75  Active Mean                 1000000 non-null  float32
#  76  Active Std                  1000000 non-null  float32
#  77  Active Max                  1000000 non-null  float32
#  78  Active Min                  1000000 non-null  float32
#  79  Idle Mean                   1000000 non-null  float32
#  80  Idle Std                    1000000 non-null  float32
#  81  Idle Max                    1000000 non-null  float32
#  82  Idle Min                    1000000 non-null  float32
#  83  Label                       1000000 non-null  category
#  84  Traffic Type                1000000 non-null  category
#  85  Traffic Subtype             1000000 non-null  category
# dtypes: category(7), float32(78), int32(1)
# memory usage: 317.2 MB

# %%
df.describe()
# Out:
#             Src Port        Dst Port        Protocol  Flow Duration  \
# count  1000000.00000  1000000.000000  1000000.000000   1.000000e+06
# mean     31818.96875       56.145504        7.471731   1.000708e+07
# std      19305.25000     1667.958137        3.745569   1.494340e+07
# min          0.00000        0.000000        0.000000   1.500000e+01
# 25%      14349.00000        0.000000        6.000000   3.562500e+04
# 50%      31975.00000        0.000000        6.000000   2.028744e+06
# 75%      48640.00000        0.000000        6.000000   1.446268e+07
# max      65535.00000    64738.000000       17.000000   1.199996e+08
#
#        Total Fwd Packet  Total Bwd packets  Total Length of Fwd Packet  \
# count    1000000.000000     1000000.000000              1000000.000000
# mean           3.596341           1.926950                  295.090912
# std          390.606659         150.571045                 2630.872803
# min            1.000000           0.000000                    0.000000
# 25%            1.000000           0.000000                   50.000000
# 50%            2.000000           1.000000                  100.000000
# 75%            2.000000           1.000000                  100.000000
# max       314483.000000      140243.000000               519561.000000
#
#        Total Length of Bwd Packet  Fwd Packet Length Max  \
# count                1.000000e+06         1000000.000000
# mean                 5.654099e+02             100.180473
# std                  2.929608e+04             223.003296
# min                  0.000000e+00               0.000000
# 25%                  0.000000e+00              50.000000
# 50%                  0.000000e+00              50.000000
# 75%                  0.000000e+00              50.000000
# max                  1.687288e+06            1368.000000
#
#        Fwd Packet Length Min  ...  Fwd Act Data Pkts  Fwd Seg Size Min  \
# count         1000000.000000  ...     1000000.000000    1000000.000000
# mean               47.448887  ...           1.484198         20.126455
# std                33.159542  ...          23.194845          7.261347
# min                 0.000000  ...           0.000000          0.000000
# 25%                50.000000  ...           0.000000         20.000000
# 50%                50.000000  ...           1.000000         20.000000
# 75%                50.000000  ...           1.000000         20.000000
# max              1368.000000  ...        5015.000000         44.000000
#
#         Active Mean    Active Std    Active Max    Active Min     Idle Mean  \
# count  1.000000e+06  1.000000e+06  1.000000e+06  1.000000e+06  1.000000e+06
# mean   4.773253e+05  8.606815e+04  5.519174e+05  4.100172e+05  5.725341e+06
# std    1.316522e+06  5.015348e+05  1.591832e+06  1.162272e+06  8.425127e+06
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  1.000970e+07
# max    8.531760e+07  7.069982e+07  9.998708e+07  8.531760e+07  1.151276e+08
#
#           Idle Std     Idle Max      Idle Min
# count   1000000.00    1000000.0  1.000000e+06
# mean     745100.25    6380120.0  5.149398e+06
# std     2578503.75    9390216.0  7.967268e+06
# min           0.00          0.0  0.000000e+00
# 25%           0.00          0.0  0.000000e+00
# 50%           0.00          0.0  0.000000e+00
# 75%           0.00   10786657.0  8.746128e+06
# max    66850696.00  115127624.0  1.151276e+08
#
# [8 rows x 79 columns]

# %%
df['Protocol'].value_counts()
# Out:
# Protocol
# 6.0     866112
# 17.0    133827
# 0.0         61
# Name: count, dtype: int64

# %%
df['Fwd Seg Size Min'].value_counts()
# Out:
# Fwd Seg Size Min
# 20.0    774320
# 8.0     133827
# 40.0     78934
# 32.0     12806
# 0.0         61
# 44.0        52
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
ax = sns.countplot(x='Traffic Type', data=df)
plt.title('Graph Traffic Types')
plt.xlabel('Traffic Type')
plt.ylabel('Count')

plt.show()

# %%
from collections import Counter

files = sorted(glob.glob("1st_task/data/chunks/part_*.parquet"))

counts = Counter()
total = 0
for f in files:
    s = pd.read_parquet(f, columns=["Traffic Type"])
    counts.update(s['Traffic Type'].astype('string').fillna('<NA>'))
    total += len(s)

top_ip, top_cnt = counts.most_common(1)[0]
top_share = top_cnt / total
print(f"unique values: {len(counts)}, top share: {top_share:.6f}")
pairs = counts.most_common()  
for ip, cnt in pairs:         
    print(ip, cnt)
# Out:
# unique values: 8, top share: 0.865326
# DoS 7490929
# Information Gathering 1038363
# Mirai 91002
# Bruteforce 35172
# Video 870
# Text 209
# Audio 190
# Background 32

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# 1) to DataFrame sorted by count
vc = (pd.Series(counts, dtype="int64")
        .sort_values(ascending=False)
        .rename_axis("Traffic Type")
        .to_frame("count"))
vc["share"] = vc["count"] / total

# 2) plot share (percent)
plt.figure(figsize=(9, 4))
bars = plt.barh(vc.index.astype(str), vc["share"].values)
plt.title(f"Traffic Type Column (n={total:,})")
plt.xlabel("Share of rows"); plt.ylabel("Traffic Type")
plt.gca().xaxis.set_major_formatter(mtick.PercentFormatter(1.0))
plt.gca().invert_yaxis()  # largest on top

for r, v in zip(bars, vc["share"].values):
    plt.text(v, r.get_y()+r.get_height()/2, f"{v:.1%}", va="center", ha="left", fontsize=9)

plt.tight_layout()
plt.show()

# %%
from collections import Counter

files = sorted(glob.glob("1st_task/data/chunks/part_*.parquet"))

counts = Counter()
total = 0
for f in files:
    s = pd.read_parquet(f, columns=["Down/Up Ratio"])
    counts.update(s['Down/Up Ratio'].astype('string').fillna('<NA>'))
    total += len(s)

top_ip, top_cnt = counts.most_common(1)[0]
top_share = top_cnt / total
print(f"unique values: {len(counts)}, top share: {top_share:.6f}")
pairs = counts.most_common()  
for ip, cnt in pairs:         
    print(ip, cnt)
# Out:
# unique values: 39, top share: 0.566332
# 0.0 4902605
# 1.0 3752591
# 2.0 995
# 3.0 300
# 4.0 111
# 5.0 97
# 7.0 17
# 6.0 15
# 8.0 3
# 214.0 2
# 272.0 2
# 238.0 2
# 271.0 1
# 255.0 1
# 180.0 1
# 302.0 1
# 311.0 1
# 249.0 1
# 276.0 1
# 280.0 1
# 341.0 1
# 335.0 1
# 269.0 1
# 306.0 1
# 198.0 1
# 284.0 1
# 233.0 1
# 251.0 1
# 309.0 1
# 327.0 1
# 250.0 1
# 288.0 1
# 274.0 1
# 240.0 1
# 261.0 1
# 296.0 1
# 14.0 1
# 15.0 1
# 10.0 1

# %%
# 1) to DataFrame sorted by count
vc = (pd.Series(counts, dtype="int64")
        .sort_values(ascending=False)
        .rename_axis("Traffic Type")
        .to_frame("count"))
vc["share"] = vc["count"] / total

# 2) plot share (percent)
plt.figure(figsize=(9, 4))
bars = plt.barh(vc.index.astype(str), vc["share"].values)
plt.title(f"Down/Up Ratio Column (n={total:,})")
plt.xlabel("Share of rows"); plt.ylabel("Down/Up Ratio")
plt.gca().xaxis.set_major_formatter(mtick.PercentFormatter(1.0))
plt.gca().invert_yaxis()  # largest on top

for r, v in zip(bars, vc["share"].values):
    plt.text(v, r.get_y()+r.get_height()/2, f"{v:10%}", va="center", ha="left", fontsize=9)

plt.tight_layout()
plt.show()

# %%
df
# Out:
#                                         Flow ID        Src IP  Src Port  \
# 0        192.168.1.90-192.168.1.3-53930-64738-6  192.168.1.90   53930.0
# 1        192.168.1.3-192.168.1.90-64738-37700-6   192.168.1.3   64738.0
# 2           192.168.1.3-192.168.1.90-22-40854-6   192.168.1.3      22.0
# 3        192.168.1.70-192.168.1.3-55422-64738-6  192.168.1.70   55422.0
# 4       192.168.1.90-192.168.1.3-59658-64738-17  192.168.1.90   59658.0
# ...                                         ...           ...       ...
# 999995      192.168.1.70-192.168.1.90-36019-0-6  192.168.1.70   36019.0
# 999996      192.168.1.70-192.168.1.90-36048-0-6  192.168.1.70   36048.0
# 999997      192.168.1.70-192.168.1.90-36037-0-6  192.168.1.70   36037.0
# 999998      192.168.1.70-192.168.1.90-20621-0-6  192.168.1.70   20621.0
# 999999      192.168.1.70-192.168.1.90-36154-0-6  192.168.1.70   36154.0
#
#               Dst IP  Dst Port  Protocol               Timestamp  \
# 0        192.168.1.3     64738       6.0  01/01/1970 07:41:46 AM
# 1       192.168.1.90     37700       6.0  01/01/1970 07:41:46 AM
# 2       192.168.1.90     40854       6.0  01/01/1970 07:41:46 AM
# 3        192.168.1.3     64738       6.0  01/01/1970 07:41:47 AM
# 4        192.168.1.3     64738      17.0  01/01/1970 07:41:50 AM
# ...              ...       ...       ...                     ...
# 999995  192.168.1.90         0       6.0  01/01/1970 04:51:49 AM
# 999996  192.168.1.90         0       6.0  01/01/1970 04:51:49 AM
# 999997  192.168.1.90         0       6.0  01/01/1970 04:51:49 AM
# 999998  192.168.1.90         0       6.0  01/01/1970 04:51:49 AM
# 999999  192.168.1.90         0       6.0  01/01/1970 04:51:49 AM
#
#         Flow Duration  Total Fwd Packet  Total Bwd packets  ...  Active Std  \
# 0          52601172.0            1701.0             1793.0  ...         0.0
# 1         119106944.0              36.0               57.0  ...   3416174.0
# 2              5589.0               1.0                1.0  ...         0.0
# 3         118166560.0            3932.0             4196.0  ...         0.0
# 4         119988384.0              25.0             6795.0  ...         0.0
# ...               ...               ...                ...  ...         ...
# 999995      2067234.0               2.0                0.0  ...         0.0
# 999996      1972233.0               2.0                0.0  ...         0.0
# 999997      2067414.0               2.0                0.0  ...         0.0
# 999998      2232870.0               2.0                0.0  ...         0.0
# 999999      2063343.0               2.0                0.0  ...         0.0
#
#         Active Max  Active Min  Idle Mean     Idle Std   Idle Max   Idle Min  \
# 0              0.0         0.0        0.0     0.000000        0.0        0.0
# 1       19996926.0  14078617.0  5001511.0  1737.400024  5003516.0  5000449.0
# 2              0.0         0.0        0.0     0.000000        0.0        0.0
# 3              0.0         0.0        0.0     0.000000        0.0        0.0
# 4              0.0         0.0        0.0     0.000000        0.0        0.0
# ...            ...         ...        ...          ...        ...        ...
# 999995         0.0         0.0        0.0     0.000000        0.0        0.0
# 999996         0.0         0.0        0.0     0.000000        0.0        0.0
# 999997         0.0         0.0        0.0     0.000000        0.0        0.0
# 999998         0.0         0.0        0.0     0.000000        0.0        0.0
# 999999         0.0         0.0        0.0     0.000000        0.0        0.0
#
#             Label  Traffic Type  Traffic Subtype
# 0          Benign         Audio            Audio
# 1          Benign         Audio            Audio
# 2          Benign         Audio            Audio
# 3          Benign         Audio            Audio
# 4          Benign         Audio            Audio
# ...           ...           ...              ...
# 999995  Malicious           DoS          DoS RST
# 999996  Malicious           DoS          DoS RST
# 999997  Malicious           DoS          DoS RST
# 999998  Malicious           DoS          DoS RST
# 999999  Malicious           DoS          DoS RST
#
# [1000000 rows x 86 columns]

# %%
paths = sorted(glob.glob("1st_task/data/chunks/part_*.parquet"))
engine = "pyarrow"
frac   = 0.2      

# find the numeric columns
num_cols = pd.read_parquet(paths[0], engine=engine).select_dtypes("number").columns.tolist()

# collect a balanced sample
parts, seen = [], 0
for p in paths:
    df1 = pd.read_parquet(p, columns=num_cols, engine=engine)
    if len(df1) == 0: 
        continue
    k = max(1, int(len(df)*frac))
    samp = df.sample(n=min(k, len(df1)), random_state=42)
    parts.append(samp)
    seen += len(samp)

S = pd.concat(parts, ignore_index=True)

# correlation 
corr = S.corr(method="pearson", numeric_only=True, min_periods=100)

plt.figure(figsize=(10,8))
sns.heatmap(corr, vmin=-1, vmax=1, cmap="coolwarm")
plt.title("Correlation (Pearson) — sampled across all chunks")
plt.tight_layout(); plt.show()

# %%
print(corr)
# Out:
#                   Src Port  Dst Port  Protocol  Flow Duration  \
# Src Port          1.000000 -0.036772  0.063970      -0.023604
# Dst Port         -0.036772  1.000000 -0.007020       0.019403
# Protocol          0.063970 -0.007020  1.000000       0.414853
# Flow Duration    -0.023604  0.019403  0.414853       1.000000
# Total Fwd Packet  0.015094  0.270940  0.019450       0.079492
# ...                    ...       ...       ...            ...
# Active Min       -0.011226  0.031184  0.417644       0.498822
# Idle Mean         0.025602 -0.016986  0.142506       0.761119
# Idle Std         -0.014164 -0.007903  0.199542       0.621224
# Idle Max          0.013273 -0.017218  0.190873       0.845910
# Idle Min          0.032562 -0.015961  0.093472       0.645914
#
#                   Total Fwd Packet  Total Bwd packets  \
# Src Port                  0.015094           0.014391
# Dst Port                  0.270940           0.349955
# Protocol                  0.019450           0.000554
# Flow Duration             0.079492           0.054878
# Total Fwd Packet          1.000000           0.696331
# ...                            ...                ...
# Active Min                0.067298           0.044555
# Idle Mean                 0.004952          -0.013506
# Idle Std                  0.014112          -0.006486
# Idle Max                  0.008930          -0.013771
# Idle Min                  0.001269          -0.012622
#
#                   Total Length of Fwd Packet  Total Length of Bwd Packet  \
# Src Port                           -0.017797                    0.016156
# Dst Port                            0.347634                    0.053295
# Protocol                            0.183483                   -0.005219
# Flow Duration                       0.261627                    0.006177
# Total Fwd Packet                    0.828758                    0.656730
# ...                                      ...                         ...
# Active Min                          0.199614                    0.001106
# Idle Mean                           0.050605                   -0.012184
# Idle Std                            0.104670                   -0.005228
# Idle Max                            0.081051                   -0.012199
# Idle Min                            0.022945                   -0.011578
#
#                   Fwd Packet Length Max  Fwd Packet Length Min  ...  \
# Src Port                      -0.081249              -0.024412  ...
# Dst Port                       0.047962               0.254880  ...
# Protocol                       0.566944               0.126307  ...
# Flow Duration                  0.630312               0.006446  ...
# Total Fwd Packet               0.067164              -0.027103  ...
# ...                                 ...                    ...  ...
# Active Min                     0.405379               0.087949  ...
# Idle Mean                      0.166277              -0.004507  ...
# Idle Std                       0.331048              -0.001102  ...
# Idle Max                       0.260162              -0.003238  ...
# Idle Min                       0.079287              -0.004847  ...
#
#                   Fwd Act Data Pkts  Fwd Seg Size Min  Active Mean  \
# Src Port                   0.005673         -0.032070    -0.020256
# Dst Port                   0.331097          0.031029     0.029400
# Protocol                   0.047661         -0.655806     0.489277
# Flow Duration              0.124553         -0.367789     0.578273
# Total Fwd Packet           0.840168          0.012327     0.068697
# ...                             ...               ...          ...
# Active Min                 0.108851         -0.308749     0.958973
# Idle Mean                  0.026153         -0.221566     0.279666
# Idle Std                   0.034478         -0.180884     0.269117
# Idle Max                   0.033861         -0.250887     0.329387
# Idle Min                   0.018197         -0.184961     0.222513
#
#                   Active Std  Active Max  Active Min  Idle Mean  Idle Std  \
# Src Port           -0.032592   -0.028856   -0.011226   0.025602 -0.014164
# Dst Port            0.008077    0.027426    0.031184  -0.016986 -0.007903
# Protocol            0.403632    0.516588    0.417644   0.142506  0.199542
# Flow Duration       0.458826    0.608363    0.498822   0.761119  0.621224
# Total Fwd Packet    0.029800    0.065553    0.067298   0.004952  0.014112
# ...                      ...         ...         ...        ...       ...
# Active Min          0.245767    0.862772    1.000000   0.282358  0.234361
# Idle Mean           0.099895    0.258779    0.282358   1.000000  0.343496
# Idle Std            0.213513    0.280224    0.234361   0.343496  1.000000
# Idle Max            0.160607    0.316813    0.318540   0.974962  0.532700
# Idle Min            0.043390    0.196103    0.236286   0.974563  0.126883
#
#                   Idle Max  Idle Min
# Src Port          0.013273  0.032562
# Dst Port         -0.017218 -0.015961
# Protocol          0.190873  0.093472
# Flow Duration     0.845910  0.645914
# Total Fwd Packet  0.008930  0.001269
# ...                    ...       ...
# Active Min        0.318540  0.236286
# Idle Mean         0.974962  0.974563
# Idle Std          0.532700  0.126883
# Idle Max          1.000000  0.902809
# Idle Min          0.902809  1.000000
#
# [79 rows x 79 columns]

# %%
cols = ['Fwd Packet Length Max','Fwd Packet Length Min']
results = df.pivot_table(index='Label',values=cols, aggfunc=['mean','std'],observed=False)

# %%
results
# Out:
#                            mean                                         std  \
#           Fwd Packet Length Max Fwd Packet Length Min Fwd Packet Length Max
# Label
# Benign               353.986481              6.202703            465.961060
# Malicious            100.124100             47.458046            222.888336
#
#
#           Fwd Packet Length Min
# Label
# Benign                15.703687
# Malicious             33.156704

# %%
results = df.pivot_table(index='Traffic Type',values=cols, aggfunc=['mean','std'],observed=False)

# %%
results
# Out:
#                               mean                        \
#              Fwd Packet Length Max Fwd Packet Length Min
# Traffic Type
# Audio                   413.605255              7.247368
# Background                0.000000              0.000000
# Bruteforce               94.370239             39.269989
# DoS                     100.333908             47.756599
#
#                                std
#              Fwd Packet Length Max Fwd Packet Length Min
# Traffic Type
# Audio                   478.635162             16.755537
# Background                0.000000              0.000000
# Bruteforce              225.611267            118.493080
# DoS                     222.785736             24.999531

# %%
rate = pd.crosstab(df['Protocol'], df['Label'], normalize='index')

# %%
rate
# Out:
# Label       Benign  Malicious
# Protocol
# 0.0       0.967213   0.032787
# 6.0       0.000154   0.999846
# 17.0      0.000224   0.999776

# %%
import glob, pandas as pd, numpy as np
import matplotlib.pyplot as plt, seaborn as sns

paths  = sorted(glob.glob("1st_task/data/chunks/part_*.parquet"))
engine = "pyarrow"
frac   = 0.1       
max_rows = None  

# discover numeric features
first    = pd.read_parquet(paths[0], engine=engine)
num_cols = first.select_dtypes('number').columns.tolist()

parts, seen = [], 0
for p in paths:
    df = pd.read_parquet(p, columns=list(dict.fromkeys(num_cols + ['Label'])),
                         engine=engine)
    if df.empty or 'Label' not in df.columns: 
        continue
    # numeric label 0/1
    df['Label_num'] = df['Label'].map({'Benign':0, 'Malicious':1}).astype('int8')

    samp = df.sample(frac=frac, random_state=42)
    parts.append(samp)
    seen += len(samp)
    if max_rows and seen >= max_rows:
        break

S = pd.concat(parts, ignore_index=True)

# features = numeric except the label columns
X = S.select_dtypes('number').drop(columns=['Label','Label_num'], errors='ignore')
# drop constants so corr isn’t NaN / divide-by-zero
X = X.loc[:, X.nunique(dropna=True) > 1]

# point-biserial (Pearson with binary y)
r = X.corrwith(S['Label_num'], method='pearson')\
     .replace([np.inf,-np.inf], np.nan).dropna().abs().sort_values(ascending=False)

# plot top-k
k = 15
plt.figure(figsize=(10,6))
sns.barplot(x=r.index[:k], y=r.values[:k])
plt.xticks(rotation=90); plt.ylabel('|r with Label|')
plt.title('Top 15 |correlation| with Label (sampled across chunks)')
plt.tight_layout(); plt.show()

# %%
print(r.head(20))
# Out:
# Fwd Act Data Pkts             0.399746
# Bwd Packet/Bulk Avg           0.399028
# Bwd Bytes/Bulk Avg            0.371022
# Total Length of Fwd Packet    0.356338
# Fwd Header Length             0.339571
# Bwd Header Length             0.285323
# PSH Flag Count                0.279086
# ACK Flag Count                0.252169
# Bwd IAT Total                 0.224002
# Total Length of Bwd Packet    0.154520
# Subflow Bwd Bytes             0.151887
# Down/Up Ratio                 0.140473
# Subflow Bwd Packets           0.081870
# Total Bwd packets             0.077799
# Active Std                    0.055769
# Bwd Packet Length Max         0.052256
# Active Max                    0.046106
# Subflow Fwd Bytes             0.041870
# Bwd Packet Length Mean        0.041755
# Bwd Segment Size Avg          0.041755
# dtype: float64
